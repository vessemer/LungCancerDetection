# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
TEST_FOLD = str(2)
VALID_FOLD = str(3)
SHIFT = 2
OVERSAMPLING = .7
UNDERSAMPLING = 8
LOWER = -1000
UPPER = 400

IN_SHAPE = [(18, 42, 42, 1), 
            (36, 20, 42, 1), 
            (36, 42, 20, 1)]

STRIDES = [(1, 2, 2), 
           (2, 1, 2), 
           (2, 2, 1)]

CPU = 6

# %%
valid, train, test = extract_paths(VALID_FOLD, TEST_FOLD)
